# %%
import numpy as np
import pandas as pd

import itertools

# %%
matches = pd.read_csv('data/matches/results.csv')
shootouts = pd.read_csv('data/matches/results.csv')
ranking = pd.read_csv('data/ranking/fifa_ranking-2021-05-27.csv')

# %%
matches = matches.loc[matches.date > '1993-01-01', ]

# %%
exceptions = ['Comoros', 'Gambia', 'Equatorial Guinea']
matches = matches.loc[matches.tournament.isin(['African Cup of Nations']) | matches.home_team.isin(exceptions) | matches.away_team.isin(exceptions), ]

# %%
GAMES = len(matches)

home_rank = np.zeros(GAMES, dtype=np.int)
away_rank = np.zeros(GAMES, dtype=np.int)
home_total_points = np.zeros(GAMES, dtype=np.float)
away_total_points = np.zeros(GAMES, dtype=np.float)
for i in range(GAMES):
    home_listing = ranking[((ranking.country_full == matches.iloc[i].home_team) & 
                            (ranking.rank_date <= matches.iloc[i].date))].sort_values(by='rank_date', ascending=False)
    
    try:
        home_rank[i] = int(home_listing.iloc[0]['rank'])
    except:
        home_rank[i] = 155
        
    away_listing = ranking[((ranking.country_full == matches.iloc[i].away_team) & 
                            (ranking.rank_date <= matches.iloc[i].date))].sort_values(by='rank_date', ascending=False)
        
    try:
        away_rank[i] = int(away_listing.iloc[0]['rank'])
    except:
        away_rank[i] = 155

# %%
matches['home_rank'] = home_rank
matches['away_rank'] = away_rank
matches.drop(labels=['tournament', 'date', 'country'], axis=1, inplace=True)
matches.neutral = matches.neutral.astype(int)

# %%
X = matches[['home_team', 'away_team', 'neutral', 'home_rank', 'away_rank']]
y1 = matches['home_score']
y2 = matches['away_score']

onehot_columns = ['home_team', 'away_team']
onehot_df = X[onehot_columns]
onehot_df = pd.get_dummies(onehot_df, columns = onehot_columns)
match_onehot_drop = X.drop(onehot_columns, axis = 1)
match_onehot = pd.concat([match_onehot_drop, onehot_df], axis = 1)

# %%
from xgboost import XGBRegressor

# home team score model
hmodel = XGBRegressor()
hmodel.fit(match_onehot.values, y1.values)
#away team score model
amodel = XGBRegressor()
amodel.fit(match_onehot.values, y2.values)
# Out:
# [18:46:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
import uuid
all_games = {}

def predict(h_country, a_country, neutral=True):
    # create vector
    cols = ['neutral', 'home_rank', 'away_rank']
    for c in onehot_df.columns.to_list():
        cols.append(c)
    df = pd.DataFrame(np.zeros((1,len(cols)), dtype=int), columns=cols)
    if neutral:
        df.neutral.iloc[0] = 1
    else:
        df.neutral.iloc[0] = 0
    
    try:
        df.home_rank.iloc[0] = ranking[((ranking.rank_date == '2021-05-27') & (ranking.country_full == h_country))]['rank'].values[0]
    except:
        df.home_rank.iloc[0] = 155
        
    try:
        df.away_rank.iloc[0] = ranking[((ranking.rank_date == '2021-05-27') & (ranking.country_full == a_country))]['rank'].values[0]
    except:
        df.away_rank.iloc[0] = 155
        
    df['home_team_'+h_country].iloc[0] = 1
    df['away_team_'+a_country].iloc[0] = 1
    #df = df[hmodel.get_booster().feature_names]
    # predict
    hscore = int(hmodel.predict(df.iloc[0].to_numpy().reshape(1,118))[0])
    ascore = int(amodel.predict(df.iloc[0].to_numpy().reshape(1,118))[0])        
    
    hval = hmodel.predict(df.iloc[0].to_numpy().reshape(1,118))[0]
    aval = amodel.predict(df.iloc[0].to_numpy().reshape(1,118))[0]
    
    #all_games[uuid.uuid4()] = {'team' : h_country, 'opponent' : a_country, 'goals_team':hscore, 'goals_opponent':ascore}
    
    return h_country, a_country, [hscore, ascore], [hval, aval]

def get_match_result(foot_model, team1, team2, elimination=False):
    
    h, a, score, scored = predict(team1, team2)
    
    all_games[uuid.uuid4()] = {'team' : team1, 'opponent' : team2, 'goals_team':score[0], 'goals_opponent':score[1]}
    
    if score[0] == score[1]:
        result = 'draw'
        looser = 'draw'
    elif score[0] > score[1]:
        result = team1
        looser = team2
    else:
        result = team2
        looser = team1
        score.reverse()
        
    
    if not elimination:
        return result, looser, score
    else:
        if result != 'draw':
            return result, looser, score
        else:
            if scored[0] >= scored[1]:
                return team1, team2, score
            else:
                return team2, team1, score

# %%
groupA = ['Burkina Faso', 'Cape Verde', 'Cameroon', 'Ethiopia']
groupB = ['Guinea', 'Malawi', 'Senegal', 'Zimbabwe']
groupC = ['Comoros', 'Gabon', 'Ghana', 'Morocco']
groupD = ['Egypt', 'Guinea-Bissau', 'Nigeria', 'Sudan']
groupE = ['Algeria', 'Ivory Coast', 'Equatorial Guinea', 'Sierra Leone']
groupF = ['Gambia', 'Mali', 'Mauritania', 'Tunisia']
groups = [groupA, groupB, groupC, groupD, groupE, groupF]
groups_names = ['A', 'B', 'C', 'D', 'E', 'F']

# %%
round_16 = pd.read_csv('data/round_16/round_16.csv', sep=';')
round_16_possibilities = pd.read_csv('data/round_16/round_16_possibilities.csv', sep=';')

# %%
def get_group_result(foot_model, group):
    ranking = pd.DataFrame({'points':[0,0,0,0], 'diff':[0,0,0,0], 'goals':[0,0,0,0]}, index=group)
    for team1, team2 in itertools.combinations(group, 2):
        result, looser, score = get_match_result(foot_model, team1, team2)
        #print(result, '-', looser,':', score)
        if result == 'draw':
            ranking.loc[[team1, team2], 'points'] += 1
            ranking.loc[[team1, team2], 'goals'] += score[0]
        else:
            ranking.loc[result, 'points'] += 3
            ranking.loc[result, 'goals'] += score[0]
            ranking.loc[looser, 'goals'] += score[1]
            ranking.loc[result, 'diff'] += score[0]-score[1]
            ranking.loc[looser, 'diff'] -= score[0]-score[1]
            
    return ranking.sort_values(by=['points','diff','goals'], ascending=False)

def get_team(code, gr, r16p):
    if len(code)==2:
        return gr.loc[code]['name']
    else:
        return gr.loc[r16p.iloc[0][code]]['name']

def get_final_result(foot_model, groups_result, r16=round_16, r16p=round_16_possibilities):
    round_of_16 = []
    quarter_finals = []
    semi_finals = []
    
    
    # SIMULATE ROUND OF 16
    for i in range(0, 8):
        round_of_16.append(get_match_result(foot_model, 
                                            get_team(r16.iloc[i]['home_team'], groups_result, r16p), 
                                            get_team(r16.iloc[i]['away_team'], groups_result, r16p), 
                                            elimination=True))
    
    
    # SIMULATE QUATER FINALS
    quarter_finals.append(get_match_result(foot_model, round_of_16[0][0], round_of_16[2][0], elimination=True))
    quarter_finals.append(get_match_result(foot_model, round_of_16[1][0], round_of_16[3][0], elimination=True))
    quarter_finals.append(get_match_result(foot_model, round_of_16[4][0], round_of_16[6][0], elimination=True))
    quarter_finals.append(get_match_result(foot_model, round_of_16[5][0], round_of_16[7][0], elimination=True))
    
    # SIMULATE SEMI FINALS
    semi_finals.append(get_match_result(foot_model, quarter_finals[0][0], quarter_finals[2][0], elimination=True))
    semi_finals.append(get_match_result(foot_model, quarter_finals[1][0], quarter_finals[3][0], elimination=True))
    
    # SIMULATE 3RD PLACE MATCH
    little_final = get_match_result(foot_model, semi_finals[0][1], semi_finals[1][1], elimination=True)
    
    # SIMULATE FINAL
    final = get_match_result(foot_model, semi_finals[0][0], semi_finals[1][0], elimination=True)
    
    return round_of_16, quarter_finals, semi_finals, little_final, final

# %%
#Needed for our african CUP
groupe_stage = {}
for i in range(0, 6):
    r = get_group_result(None, groups[i])
    for k in range(1, 5):
        groupe_stage[groups_names[i]+str(k)] = {'group' : groups_names[i],
                                                'name' : r.index[k-1], 
                                                'points' : r.iloc[k-1]['points'], 
                                                'goals_difference' : r.iloc[k-1]['goals'], 
                                                'goals_scored' : r.iloc[k-1]['goals'], 
                                                'rank' : k}

combination = ''.join(list(pd.DataFrame.from_dict(groupe_stage, orient='index').query('rank==3')\
                           .sort_values(by=['points', 'goals_difference', 'goals_scored'], ascending=False).group[0:4].sort_values()))

groups_ranking = pd.DataFrame.from_dict(groupe_stage, orient='index')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
round_of_16, quarter_finals, semi_finals, little_final, final = get_final_result(None, 
                                                                                 groups_ranking, 
                                                                                 round_16, 
                                                                                 round_16_possibilities.query('combination=="{0}"'.format(combination)))

# %%
get_match_result(None, 'Egypt', 'Tunisia', elimination=True)
# Out:
# ('Egypt', 'Tunisia', [1, 0])

# %%
pd.DataFrame.from_dict(all_games, orient='index')
# Out:
#                                                    team           opponent  \
# 01dbbc06-7ae3-444e-8cac-72ba6f169720             Guinea             Malawi
# 0afff280-43ac-48ad-ad8c-d4643861fee1              Egypt              Ghana
# 0fef6d24-ea51-44ab-adf4-7152581697bf              Gabon            Morocco
# 110ab8d7-3b01-488d-a672-bc09af54fd1c      Guinea-Bissau              Sudan
# 1d0225fa-50c7-45d2-bbe2-02d3ada9d187            Comoros              Ghana
# 20a3c019-b09c-4464-8050-f489ad70d30c            Senegal           Zimbabwe
# 29d7d057-8ee0-4662-a1f7-225cab58349e        Ivory Coast  Equatorial Guinea
# 2a700905-2d36-406e-97f5-ba17e595da23           Cameroon            Morocco
# 2a8cee43-045f-4f61-81e0-0442f0a14be4       Burkina Faso           Ethiopia
# 3429dc88-0b12-4904-90a4-3c8152c3dca3            Nigeria              Sudan
# 36c87af1-a98b-439a-a5b1-7194a0a0b08d            Algeria            Nigeria
# 3de87cab-85d8-434b-8b83-99e7c9fef984              Egypt               Mali
# 3fa26413-e570-4d7e-8d9a-a2a416789949        Ivory Coast       Sierra Leone
# 4a772f9d-f23a-40ee-a041-9c290c7c9f44            Algeria  Equatorial Guinea
# 4b09c199-8f22-45c4-8843-7a085e99ac9c            Algeria        Ivory Coast
# 5b026544-1a17-4810-a224-6efcdd786417              Egypt      Guinea-Bissau
# 5bef4d97-3b53-4168-a106-b5958ee63ddb           Cameroon            Senegal
# 5f855945-400b-4b07-9307-b2174427733a         Mauritania            Tunisia
# 6490c01f-c6f1-499a-ac44-723cb61950e3       Burkina Faso              Gabon
# 66002e8c-a9cb-4a96-96eb-54ca52a0419b         Cape Verde           Cameroon
# 6a7b42a6-8d8f-487b-b681-657ed708dc3b           Cameroon           Ethiopia
# 724493dd-9490-4d2f-9445-d485bc72acaf            Senegal      Guinea-Bissau
# 7572f030-9d19-4d09-a3a0-d95adf83abbb  Equatorial Guinea       Sierra Leone
# 7e1ec04a-80dc-48f6-9490-a5ca5630c12c               Mali            Tunisia
# 812bb63a-7862-4b57-896a-6c631de3d208             Guinea            Senegal
# 8a97f89e-833d-4431-89f7-95ecbf31fb4b             Gambia         Mauritania
# aa8d8238-bfef-4b81-a6e8-e099db31ecd5             Malawi            Senegal
# adaf7b0d-50eb-4be5-be31-79a60f5091ce             Malawi            Tunisia
# bcb4a276-5b2b-4955-981f-d338d1c79141              Egypt              Sudan
# c0b947c9-10f0-4744-8126-00c04ed2291d            Comoros              Gabon
# c0d00aab-a901-4456-b6a1-501a0c7fc80a      Guinea-Bissau            Nigeria
# c153d7eb-3242-4bb5-a58f-97e581b9c0c7       Burkina Faso              Ghana
# c260eb14-239c-4967-ae17-8315795c1f7e            Algeria       Sierra Leone
# c393da7d-90ef-4aec-9928-9b8bab06e731               Mali         Mauritania
# c3d1fbaf-616b-4bd7-bc23-0e9f4ba27614             Guinea           Zimbabwe
# ca4979ba-4cf3-405e-8d98-2cdce2e40921             Gambia            Tunisia
# cac36a39-5076-48a7-8b53-e995cfe8f6bc              Egypt             Guinea
# cb41ff22-a886-478f-bffb-893e2cd108c7           Cameroon            Tunisia
# cba476e9-63fe-4a4d-9a93-7ee13b2a0618       Burkina Faso           Cameroon
# d355f8f4-f829-4201-b05e-c5b8b031f6ce             Malawi           Zimbabwe
# d9c65acf-0b54-4555-8c87-eb2daccacac3              Ghana         Cape Verde
# e15fbd46-b226-481b-95fe-cfa393e451d0            Tunisia              Ghana
# e4a74aad-fbf6-43f0-9cca-2f3b1c39ce76              Gabon              Ghana
# e9615ebe-b296-4d5d-9e80-8fc35051b858              Ghana            Morocco
# ec1aaecf-e926-4db9-b822-4db603ea7aeb             Gambia               Mali
# ee913290-fcd8-4465-8fe6-2a2622d16782            Tunisia            Algeria
# f0e38b4d-0ed8-4379-90c6-3b81d519237d       Burkina Faso         Cape Verde
# f53e15d1-7449-40b6-bf25-0443c20138de            Comoros            Morocco
# fb5a61eb-68d8-473b-825d-8a1d8e9dd96f           Cameroon              Egypt
# fc071dd1-73dc-4ad1-b853-e39692e789d2         Cape Verde           Ethiopia
# fc553472-d45c-40f8-ad2f-549a39ea4923              Egypt            Nigeria
# ff1bbf91-ae44-4d93-a0bd-49ff83da54b0               Mali        Ivory Coast
#
#                                       goals_team  goals_opponent
# 01dbbc06-7ae3-444e-8cac-72ba6f169720           1               1
# 0afff280-43ac-48ad-ad8c-d4643861fee1           1               0
# 0fef6d24-ea51-44ab-adf4-7152581697bf           1               1
# 110ab8d7-3b01-488d-a672-bc09af54fd1c           1               0
# 1d0225fa-50c7-45d2-bbe2-02d3ada9d187           0               1
# 20a3c019-b09c-4464-8050-f489ad70d30c           1               0
# 29d7d057-8ee0-4662-a1f7-225cab58349e           2               0
# 2a700905-2d36-406e-97f5-ba17e595da23           1               0
# 2a8cee43-045f-4f61-81e0-0442f0a14be4           1               0
# 3429dc88-0b12-4904-90a4-3c8152c3dca3           1               0
# 36c87af1-a98b-439a-a5b1-7194a0a0b08d           1               1
# 3de87cab-85d8-434b-8b83-99e7c9fef984           1               0
# 3fa26413-e570-4d7e-8d9a-a2a416789949           2               0
# 4a772f9d-f23a-40ee-a041-9c290c7c9f44           2               0
# 4b09c199-8f22-45c4-8843-7a085e99ac9c           1               0
# 5b026544-1a17-4810-a224-6efcdd786417           1               0
# 5bef4d97-3b53-4168-a106-b5958ee63ddb           1               0
# 5f855945-400b-4b07-9307-b2174427733a           0               1
# 6490c01f-c6f1-499a-ac44-723cb61950e3           1               1
# 66002e8c-a9cb-4a96-96eb-54ca52a0419b           0               0
# 6a7b42a6-8d8f-487b-b681-657ed708dc3b           1               0
# 724493dd-9490-4d2f-9445-d485bc72acaf           1               0
# 7572f030-9d19-4d09-a3a0-d95adf83abbb           1               1
# 7e1ec04a-80dc-48f6-9490-a5ca5630c12c           1               1
# 812bb63a-7862-4b57-896a-6c631de3d208           1               1
# 8a97f89e-833d-4431-89f7-95ecbf31fb4b           1               1
# aa8d8238-bfef-4b81-a6e8-e099db31ecd5           0               1
# adaf7b0d-50eb-4be5-be31-79a60f5091ce           0               1
# bcb4a276-5b2b-4955-981f-d338d1c79141           2               0
# c0b947c9-10f0-4744-8126-00c04ed2291d           1               1
# c0d00aab-a901-4456-b6a1-501a0c7fc80a           0               1
# c153d7eb-3242-4bb5-a58f-97e581b9c0c7           0               0
# c260eb14-239c-4967-ae17-8315795c1f7e           1               0
# c393da7d-90ef-4aec-9928-9b8bab06e731           1               0
# c3d1fbaf-616b-4bd7-bc23-0e9f4ba27614           1               1
# ca4979ba-4cf3-405e-8d98-2cdce2e40921           0               1
# cac36a39-5076-48a7-8b53-e995cfe8f6bc           1               0
# cb41ff22-a886-478f-bffb-893e2cd108c7           1               0
# cba476e9-63fe-4a4d-9a93-7ee13b2a0618           1               1
# d355f8f4-f829-4201-b05e-c5b8b031f6ce           1               0
# d9c65acf-0b54-4555-8c87-eb2daccacac3           1               0
# e15fbd46-b226-481b-95fe-cfa393e451d0           1               0
# e4a74aad-fbf6-43f0-9cca-2f3b1c39ce76           0               1
# e9615ebe-b296-4d5d-9e80-8fc35051b858           0               0
# ec1aaecf-e926-4db9-b822-4db603ea7aeb           0               1
# ee913290-fcd8-4465-8fe6-2a2622d16782           1               1
# f0e38b4d-0ed8-4379-90c6-3b81d519237d           1               0
# f53e15d1-7449-40b6-bf25-0443c20138de           0               1
# fb5a61eb-68d8-473b-825d-8a1d8e9dd96f           0               0
# fc071dd1-73dc-4ad1-b853-e39692e789d2           1               0
# fc553472-d45c-40f8-ad2f-549a39ea4923           1               0
# ff1bbf91-ae44-4d93-a0bd-49ff83da54b0           1               0
